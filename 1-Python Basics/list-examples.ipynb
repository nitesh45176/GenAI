# %% [markdown]
# ## __Real-World Examples Using Lists in Python__
#
# Lists are one of the most commonly used data structures in Python, thanks to their versatility and ease of use. Here are several practical examples that illustrate their use in real-world scenarios

# %% [markdown]
# Example 1. Manage A To Do List

# %%
todo_list = ['Buy groceries','Study','Sports','Running']

## Adding tasks
todo_list.append('meeting')
todo_list.append('gym')

## Removing completed task
todo_list.remove('gym')

## checking if task is in list
if 'Study' in todo_list:
    print("Study at 4pm")

print("Remaining list")
for task in todo_list:
    print(task)
# Out:
# Study at 4pm
# Remaining list
# Buy groceries
# Study
# Sports
# Running
# meeting
