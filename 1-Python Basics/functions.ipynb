# %% [markdown]
# ## Functions Examples

# %% [markdown]
# ### Example 1: Temperature Conversion

# %%
def temp_conv(temp,unit):
    if unit=='C':
        return temp * 9/5 + 32
    elif unit=='F':
        return (temp-32) * 5/9
    else:
        return NULL

temp_conv(25,'C')
temp_conv(77,'F')

# %%
numbers =[1,2,3,4,5]
list(map(lambda x:x**x, numbers))
# Out:
# [1, 4, 27, 256, 3125]
