# %% [markdown]
# ### __Standard Library Overview__
#
# Python's Standard Library is a vast collection of modules and packages that come bundled with Python, providing a wide range of functionalities out of the box. Here's an overview of some of the most commonly used modules and packages in the Python Standard Library.

# %%
import os
print(os.getcwd())
# Out:
# c:\Users\Lenovo\Desktop\Python\1-Python Basics

# %%
os.mkdir('test_dir')

# %%
## High level operation on files and collection of files
import shutil
shutil.copy('source.txt','destination.txt')
# Out:
# 'destination.txt'

# %%
## Data serialization
import json
data={'name':'Krish', 'age':24}

json_str = json.dumps(data)
print(json_Str)
print(type(json_str))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 6
#       2 import json
#       3 data={'name':'Krish', 'age':24}
#       4
#       5 json_str = json.dumps(data)
# ----> 6 print(json_Str)
#       7 print(type(json_str))
#
# NameError: name 'json_Str' is not defined

# %%
## csv

import csv 

with open('example.csv',mode='w', newline='') as file:
    writer=csv.writer(file)
    writer.writerow(['name','age'])
    writer.writerow(['krish',32]) 

with open('example.csv', mode='r') as file:
    reader=csv.reader(file)
    for row in reader:
        print(row)
# Out:
# ['name', 'age']
# ['krish', '32']

# %%
## datetime
